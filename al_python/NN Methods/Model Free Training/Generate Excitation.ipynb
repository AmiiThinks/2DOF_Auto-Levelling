# %%
from simulation_tools import PRBS
from matplotlib import pyplot as plt
import numpy as np

# %%
sig_gen = PRBS()
aprbs = sig_gen.generate_APRBS(10000, 200, 180)
aprbs_buttered = sig_gen.apply_butter(aprbs) #Apply butterworth filter

plt.plot(aprbs_buttered)

# %%
np.savetxt('aprbs_flex.csv', aprbs_buttered)
